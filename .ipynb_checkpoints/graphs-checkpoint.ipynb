# %%
import sklearn
import os 
import tifffile
from sklearn.feature_extraction import image
import numpy as np
import matplotlib.pyplot as plt
import utils
from sklearn.cluster import KMeans
from scipy.spatial import distance
import os
import sys

# %%
import sknetwork as skn

# %%
## Load the tile
## we will not use utils get band as having a array is better here 

def get_array(folder):
    # we want all the bands to create the dataset
    L = ['B01','B02','B03','B04','B05','B06','B07','B08','B8A','B09','B11','B12']
    path = 'data/'+ folder
    inside_folder = os.listdir(path)

    # store the bands
    #band_array = np.zeros((600,1400,len(L)))
    band_array = np.zeros((90,183,len(L)))
    ## load wanted spectral bands
    i = 0
    for raw_band in inside_folder:
        for desired_band in L:
            if desired_band in raw_band:
                img = tifffile.imread(os.path.join(path,raw_band))
                # crop the image not to have problems when creating patchs
                #band_array[:,:,i] = img[:600,:1400]
                band_array[:,:,i] = img
                i+=1
    return band_array

# %%
img = get_array('2019_05_03_M')[:,75:,[2,7]]
img.shape
# Out:
# (90, 108, 2)

# %%
plt.imshow(img[:,:,1])

# %%
def kmeans(arrays, nb_clust):
    arrays_flat=np.array([arrays[:,:,i].flatten() for i in range(arrays.shape[2])])
    X=(np.transpose(arrays_flat))
    kmeans = KMeans(n_clusters=nb_clust,  init='k-means++', n_init=10, max_iter=1000) # tester k-means méthod max?
    kmeans.fit(X)
    labels=kmeans.labels_
    clust = kmeans.cluster_centers_
    plastic_index = 0
    nb = 99999
    nb_2 = 0
    img_labels = labels.reshape(90,183-75)
    
    plt.figure()
    plt.imshow(img_labels)
    plt.title('labels after kmeans')
    
    return img_labels,clust

# %%
def delete_land(img):
    labels,clust = kmeans(img, 2)
    spectral_sign = {'water': [ 0.10384066, 0.13632251], 'ground':[ 0.03796409, 0.03244987]}
    d1 = distance.euclidean(clust[0], spectral_sign['ground'])
    d2 = distance.euclidean(clust[1], spectral_sign['ground'])
    ground_label = 100
     
    if d1<d2:
        ground_label = 1
    else : 
        ground_label = 0
        
    result = img.copy()
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if labels[i,j] == ground_label:
                result[i,j] = spectral_sign['water']

    plt.figure()    
    plt.imshow(result[:,:,1])
    return result

# %%
result = delete_land(img)

# %%
bands = ['B02','B03','B04','B08']

spectral_sign_4 = {'water': [ 0.10384066, 0.13632251, 0.16474463, 
       0.3045134], 'ground':[ 0.03796409, 0.03244987, 0.02011696, 0.01891139]}

# %%
graph = image.img_to_graph(result[:,:,1])

# %%
type(graph)
#print(graph)
#graph = graph.toarray()
# Out:
# scipy.sparse.coo.coo_matrix

# %%
graph
# Out:
# <9720x9720 sparse matrix of type '<class 'numpy.float64'>'
# 	with 48204 stored elements in COOrdinate format>

# %%
from sklearn.cluster import SpectralClustering

clustering = SpectralClustering(n_clusters=3, n_components = 5).fit(graph)
# Out:
# C:\Users\basil\Anaconda3\envs\imsat\lib\site-packages\sklearn\cluster\_spectral.py:504: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn("The spectral clustering API has changed. ``fit``"

# %%
clustering.labels_.shape
# Out:
# (9720,)

# %%
img_labels = clustering.labels_.reshape(90,183-75)

# %%
plt.figure(figsize = (100,100))
plt.subplot(131)
plt.imshow(img[:,:,1])
plt.subplot(132)
plt.imshow(img_labels[:,:])

plt.subplot(133)
plt.imshow(result[:,:,1])

# %%
test = result[:,:,1].flatten()
plt.figure(figsize = (10,10))
plt.plot(test[clustering.labels_ == 0])
